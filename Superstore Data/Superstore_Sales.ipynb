# %%
import numpy as ny
import pandas as pd
import matplotlib.pyplot as pyl
import seaborn as sns

# %%
df = pd.read_excel('Superstore_USA.xlsx')

# %%
df.head(5)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
df.shape
# Out:
# (9426, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9354 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
pd.isnull(df)
# Out:
#       Row ID  Order Priority  Discount  Unit Price  Shipping Cost  \
# 0      False           False     False       False          False
# 1      False           False     False       False          False
# 2      False           False     False       False          False
# 3      False           False     False       False          False
# 4      False           False     False       False          False
# ...      ...             ...       ...         ...            ...
# 9421   False           False     False       False          False
# 9422   False           False     False       False          False
# 9423   False           False     False       False          False
# 9424   False           False     False       False          False
# 9425   False           False     False       False          False
#
#       Customer ID  Customer Name  Ship Mode  Customer Segment  \
# 0           False          False      False             False
# ...

# %%
pd.isnull(df).sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
df['Product Base Margin'].fillna(df['Product Base Margin'].mean(),inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9364\3821109820.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Product Base Margin'].fillna(df['Product Base Margin'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %% [markdown]
# ## Order Priority

# %%
df['Order Priority'].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Critical            1
# Name: count, dtype: int64

# %%
df['Order Priority'].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %%
df['Order Priority'].replace('Critical ', 'Critical')
# Out:
# 0       Not Specified
# 1                High
# 2       Not Specified
# 3       Not Specified
# 4       Not Specified
#             ...
# 9421         Critical
# 9422         Critical
# 9423    Not Specified
# 9424             High
# 9425    Not Specified
# Name: Order Priority, Length: 9426, dtype: object

# %%
pyl.figure(figsize=(5,3))
sns.countplot(x='Order Priority', data=df)
pyl.show()

# %%
pyl.figure(figsize=(5,5))
pyl.title('Count of Order Priority')
ax=sns.countplot(x='Order Priority', data=df)
for count in ax.containers:
    ax.bar_label(count)
pyl.savefig('Count of Order Priority.jpg')

# %% [markdown]
# ## Ship Mode

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %%
x = df['Ship Mode'].value_counts().index
y = df['Ship Mode'].value_counts().values
pyl.figure(figsize=(5,5))
pyl.pie(y,labels=x,autopct='%0.2f%%', startangle=90)
pyl.show()
pyl.savefig('Ship Mode Piechart.jpg')

# %%
pyl.figure(figsize=(5,5))
ax=sns.countplot(x='Ship Mode', data=df, hue='Product Category')
for count in ax.containers:
    ax.bar_label(count)
pyl.show()

# %% [markdown]
# #### From above figure we can see that the count of Office Supplies are more using Regular Air shipping and express Air shipping, and in Trusk Delivery the furniture is more.

# %% [markdown]
# ## Customer Segment

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
pyl.figure(figsize=(7,5))
ax = sns.countplot(x='Customer Segment', data=df)
for count in ax.containers:
    ax.bar_label(count)
pyl.show(ax)

# %%
pyl.figure(figsize=(7,5))
ax = sns.countplot(x='Customer Segment', data=df, hue='Region')
pyl.show(ax)

# %%
pyl.figure(figsize=(7,5))
ax = sns.countplot(x='Region', data=df, hue='Customer Segment')
pyl.show(ax)

# %% [markdown]
# #### from above graphs we can see that for every region the corporate customers are more than others.

# %% [markdown]
# ## Product Category

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
pyl.figure(figsize=(7,5))
ax = sns.countplot(x='Product Category', data=df)
pyl.show(ax)

# %%
pyl.figure(figsize=(7,5))
ax = sns.countplot(x='Product Category', data=df[df['Product Category']=='Office Supplies'], hue='Product Sub-Category')
pyl.show(ax)

# %%
pyl.figure(figsize=(7,5))
ax = sns.countplot(x='Product Category', data=df[df['Product Category']=='Technology'], hue='Product Sub-Category')
pyl.show(ax)

# %%
pyl.figure(figsize=(7,5))
ax = sns.countplot(x='Product Category', data=df[df['Product Category']=='Furniture'], hue='Product Sub-Category')
pyl.show(ax)

# %% [markdown]
# #### From above 3 figures we can say that in office supplies the papers are more selling, ans in Technoloy telephones are more selling and in Furniture the Office Furnishing products are more selling

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
df['Order Year'] = df['Order Date'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9426 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
df['Order Year'].value_counts()
# Out:
# Order Year
# 2013    3054
# 2012    2241
# 2011    2179
# 2010    1952
# Name: count, dtype: int64

# %%
pyl.figure(figsize=(7,5))
ax = sns.countplot(x='Order Year', data=df)
pyl.show(ax)

# %%
pyl.figure(figsize=(7,5))
ax = sns.countplot(x='Order Year', data=df, hue='Product Category')
pyl.show(ax)

# %% [markdown]
# #### From above chart we able to get that Year by year the Order in Office supplies are increases

# %%
pyl.figure(figsize=(7,5))
ax = sns.barplot(x='Product Category', y='Profit', data=df, estimator='sum')
pyl.show(ax)

# %% [markdown]
# #### From above figure we can say that the profit in Technology is more than others

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'Order Year'],
#       dtype='object')

# %%
df['State or Province'].value_counts()[:5]
# Out:
# State or Province
# California    1021
# Texas          646
# Illinois       584
# New York       574
# Florida        522
# Name: count, dtype: int64

# %%
pyl.figure(figsize=(7,5))
ax = sns.barplot(x='Product Category', y='Product Base Margin', data=df, estimator='sum')
pyl.show(ax)

# %% [markdown]
# #### In the above figure we can see that the margin in Office supplies are more.
